# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('./train.csv')

# %%
train
# Out:
#             Timestamp  n-payments-per-block  ...      difficulty  hash-rate
# 0      11/1/2018 0:00                  2851  ...   7180000000000   51977956
# 1      11/2/2018 0:00                  3487  ...   7180000000000   52845282
# 2      11/3/2018 0:00                  2448  ...   7180000000000   52846859
# 3      11/4/2018 0:00                  2895  ...   7180000000000   54123854
# 4      11/5/2018 0:00                  3192  ...   7180000000000   53309080
# ...               ...                   ...  ...             ...        ...
# 1082  10/18/2021 0:00                  4421  ...  19900000000000  144095201
# 1083  10/19/2021 0:00                  4561  ...  20100000000000  144403298
# 1084  10/20/2021 0:00                  4536  ...  20100000000000  147578458
# 1085  10/21/2021 0:00                  4907  ...  20100000000000  144953486
# 1086  10/22/2021 0:00                  4256  ...  20100000000000  146706532
#
# [1087 rows x 8 columns]

# %%
train
# Out:
#             Timestamp  n-payments-per-block  ...      difficulty  hash-rate
# 0      11/1/2018 0:00                  2851  ...   7180000000000   51977956
# 1      11/2/2018 0:00                  3487  ...   7180000000000   52845282
# 2      11/3/2018 0:00                  2448  ...   7180000000000   52846859
# 3      11/4/2018 0:00                  2895  ...   7180000000000   54123854
# 4      11/5/2018 0:00                  3192  ...   7180000000000   53309080
# ...               ...                   ...  ...             ...        ...
# 1082  10/18/2021 0:00                  4421  ...  19900000000000  144095201
# 1083  10/19/2021 0:00                  4561  ...  20100000000000  144403298
# 1084  10/20/2021 0:00                  4536  ...  20100000000000  147578458
# 1085  10/21/2021 0:00                  4907  ...  20100000000000  144953486
# 1086  10/22/2021 0:00                  4256  ...  20100000000000  146706532
#
# [1087 rows x 8 columns]

# %%
train['difficulty'] = train['difficulty'] / 10000000000
# 10,000,000,000 나누기

# %%
columns = ['n-payments-per-block', 'miners-revenue', 'trade-volume',
        'n-unique-addresses', 'difficulty', 'hash-rate']

# float -> int
for i in columns:
  train[i] = train[i].astype('int')

# %%
columns = ['miners-revenue', 'trade-volume',
        'n-unique-addresses']
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train[columns] = sc.fit_transform(train[columns])

# %%
x_train = train.iloc[:,:-1]
y_train = train.iloc[:,-1]

# %%
x_train
# Out:
#             Timestamp  n-payments-per-block  ...  n-unique-addresses  difficulty
# 0      11/1/2018 0:00                  2851  ...            0.303509         718
# 1      11/2/2018 0:00                  3487  ...            0.397255         718
# 2      11/3/2018 0:00                  2448  ...            0.222781         718
# 3      11/4/2018 0:00                  2895  ...            0.168047         718
# 4      11/5/2018 0:00                  3192  ...            0.344485         718
# ...               ...                   ...  ...                 ...         ...
# 1082  10/18/2021 0:00                  4421  ...            0.708833        1990
# 1083  10/19/2021 0:00                  4561  ...            0.596618        2010
# 1084  10/20/2021 0:00                  4536  ...            0.446883        2010
# 1085  10/21/2021 0:00                  4907  ...            0.381261        2010
# 1086  10/22/2021 0:00                  4256  ...            0.613513        2010
#
# [1087 rows x 7 columns]

# %%
y_train
# Out:
# 0        51977956
# 1        52845282
# 2        52846859
# 3        54123854
# 4        53309080
#           ...
# 1082    144095201
# 1083    144403298
# 1084    147578458
# 1085    144953486
# 1086    146706532
# Name: hash-rate, Length: 1087, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train, test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
y_test
# Out:
# 746     127563115
# 56       39671825
# 684     136485692
# 896     165788554
# 723     133536442
#           ...
# 1043    136270749
# 661     119391426
# 894     169731989
# 828     152461827
# 429     103031752
# Name: hash-rate, Length: 218, dtype: int64

# %%
train = pd.concat([train,y_train],axis=1)

# %%
y_test = y_test/1000000

# %%
train['hash-rate'] = train['hash-rate']/1000000

# %%
train['hash-rate']
# Out:
# 328      90.858160
# 523     104.430894
# 1086    146.706532
# 215      51.200279
# 256      64.994549
#            ...
# 330      91.434682
# 466     110.381153
# 121      44.696377
# 1044    135.548079
# 860     156.532985
# Name: hash-rate, Length: 869, dtype: float64

# %%
train.to_csv('train.csv',index=True)
test.to_csv('test.csv',index=True)

# %%
test
# Out:
#             Timestamp  n-payments-per-block  ...  n-unique-addresses  difficulty
# 746   11/16/2020 0:00                  3880  ...            0.634080        1700
# 56    12/27/2018 0:00                  2606  ...            0.193370         511
# 684    9/15/2020 0:00                  4366  ...            0.587778        1730
# 896    4/15/2021 0:00                  5410  ...            0.691191        2320
# 723   10/24/2020 0:00                  4027  ...            0.451856        2000
# ...               ...                   ...  ...                 ...         ...
# 1043    9/9/2021 0:00                  4869  ...            0.289209        1840
# 661    8/23/2020 0:00                  3506  ...            0.602211        1690
# 894    4/13/2021 0:00                  5727  ...            0.659441        2310
# 828     2/6/2021 0:00                  4734  ...            0.924461        2140
# 429     1/4/2020 0:00                  2753  ...            0.231900        1380
#
# [218 rows x 7 columns]

# %%
y_test.to_csv('submit_sample.csv',index=True)
